# %% [markdown]
# HW 3

# %% [markdown]
# Problem 1 and Problem 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.svm import LinearSVC

df = pd.read_csv('heart.csv')
df.head(303)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
feat1 = 'age'
feat2 = 'chol'
target = 'target'

plt.scatter(df[feat1], df[feat2], c=df[target])
plt.xlabel(feat1)
plt.ylabel(feat2)
plt.title("Age vs Serum Cholestoral")
plt.show()

# %%
feat1 = 'age'
feat2 = 'trestbps'
target = 'target'

plt.scatter(df[feat1], df[feat2], c=df[target])
plt.xlabel(feat1)
plt.ylabel(feat2)
plt.title("Age vs Resting Blood Pressure")
plt.show()

# %%
feat1 = 'age'
feat2 = 'thalach'
target = 'target'

plt.scatter(df[feat1], df[feat2], c=df[target])
plt.xlabel(feat1)
plt.ylabel(feat2)
plt.title("Age vs Maximum Heart Rate")
plt.show()

# %%
feat1 = 'age'
feat2 = 'oldpeak'
target = 'target'

plt.scatter(df[feat1], df[feat2], c=df[target])
plt.xlabel(feat1)
plt.ylabel(feat2)
plt.title("Age vs Old Peak")
plt.show()

# %%
feat1 = 'trestbps'
feat2 = 'chol'
target = 'target'

plt.scatter(df[feat1], df[feat2], c=df[target])
plt.xlabel(feat1)
plt.ylabel(feat2)
plt.title("Resting Blood Pressure vs Serum Cholestoral")
plt.show()

# %%
feat1 = 'trestbps'
feat2 = 'thalach'
target = 'target'

plt.scatter(df[feat1], df[feat2], c=df[target])
plt.xlabel(feat1)
plt.ylabel(feat2)
plt.title("Resting Blood Pressure vs Maximum Heart Rate")
plt.show()

# %%
feat1 = 'trestbps'
feat2 = 'oldpeak'
target = 'target'

plt.scatter(df[feat1], df[feat2], c=df[target])
plt.xlabel(feat1)
plt.ylabel(feat2)
plt.title("Resting Blood Pressure vs Oldpeak")
plt.show()

# %%
feat1 = 'chol'
feat2 = 'thalach'
target = 'target'

plt.scatter(df[feat1], df[feat2], c=df[target])
plt.xlabel(feat1)
plt.ylabel(feat2)
plt.title("Serum Cholestoral vs Maximum Heart Rate")
plt.show()

# %%
feat1 = 'chol'
feat2 = 'oldpeak'
target = 'target'

plt.scatter(df[feat1], df[feat2], c=df[target])
plt.xlabel(feat1)
plt.ylabel(feat2)
plt.title("Serum Cholestoral vs OldPeak")
plt.show()

# %%
feat1 = 'thalach'
feat2 = 'oldpeak'
target = 'target'

plt.scatter(df[feat1], df[feat2], c=df[target])
plt.xlabel(feat1)
plt.ylabel(feat2)
plt.title("Maximum Heart Rate vs OldPeak")
plt.show()

# %%
feat1 = 'age'
feat2 = 'chol'
target = 'target'

plt.scatter(df[feat1], df[feat2], c=df[target])
plt.xlabel(feat1)
plt.ylabel(feat2)
plt.title("Age vs Serum Cholestoral")
plt.show()

X = df[[feat1, feat2]]
y = df[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
log_reg_model = LogisticRegression()
log_reg_model.fit(X_train, y_train)
y_pred = log_reg_model.predict(X_test)
accuracyScore = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1Score = f1_score(y_test, y_pred)
print("Logistic Regression Accuracy Score: ", accuracyScore)
print("Logistic Regression Precison Score: ", precision)
print("Logistic Regression Recall Score: ", recall)
print("Logistic Regression F1 Score: ", f1Score)

print('\n')

lin_svc_model = LinearSVC()
lin_svc_model.fit(X_train, y_train)
y_pred = lin_svc_model.predict(X_test)
accuracyScore = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1Score = f1_score(y_test, y_pred)
print("Linear SVC Accuracy Score: ", accuracyScore)
print("Linear SVC Precison Score: ", precision)
print("Linear SVC Recall Score: ", recall)
print("Linear SVC F1 Score: ", f1Score)
# Out:
# Logistic Regression Accuracy Score:  0.6263736263736264
# Logistic Regression Precison Score:  0.6428571428571429
# Logistic Regression Recall Score:  0.72
# Logistic Regression F1 Score:  0.6792452830188679
#
#
# Linear SVC Accuracy Score:  0.5934065934065934
# Linear SVC Precison Score:  0.6140350877192983
# Linear SVC Recall Score:  0.7
# Linear SVC F1 Score:  0.6542056074766355

# %%
feat1 = 'thalach'
feat2 = 'oldpeak'
target = 'target'

plt.scatter(df[feat1], df[feat2], c=df[target])
plt.xlabel(feat1)
plt.ylabel(feat2)
plt.title("Maximum Heart Rate vs Oldpeak")
plt.show()

X = df[[feat1, feat2]]
y = df[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
log_reg_model = LogisticRegression()
log_reg_model.fit(X_train, y_train)
y_pred = log_reg_model.predict(X_test)
accuracyScore = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1Score = f1_score(y_test, y_pred)
print("Logistic Regression Accuracy Score: ", accuracyScore)
print("Logistic Regression Precison Score: ", precision)
print("Logistic Regression Recall Score: ", recall)
print("Logistic Regression F1 Score: ", f1Score)

print('\n')

lin_svc_model = LinearSVC()
lin_svc_model.fit(X_train, y_train)
y_pred = lin_svc_model.predict(X_test)
accuracyScore = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1Score = f1_score(y_test, y_pred)
print("Linear SVC Accuracy Score: ", accuracyScore)
print("Linear SVC Precison Score: ", precision)
print("Linear SVC Recall Score: ", recall)
print("Linear SVC F1 Score: ", f1Score)
# Out:
# Logistic Regression Accuracy Score:  0.7472527472527473
# Logistic Regression Precison Score:  0.7547169811320755
# Logistic Regression Recall Score:  0.8
# Logistic Regression F1 Score:  0.7766990291262136
#
#
# Linear SVC Accuracy Score:  0.7472527472527473
# Linear SVC Precison Score:  0.7547169811320755
# Linear SVC Recall Score:  0.8
# Linear SVC F1 Score:  0.7766990291262136

# %%
feat1 = 'trestbps'
feat2 = 'thalach'
target = 'target'

plt.scatter(df[feat1], df[feat2], c=df[target])
plt.xlabel(feat1)
plt.ylabel(feat2)
plt.title("Resting Blood Pressure vs Maximum Heart Rate")
plt.show()

X = df[[feat1, feat2]]
y = df[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
log_reg_model = LogisticRegression()
log_reg_model.fit(X_train, y_train)
y_pred = log_reg_model.predict(X_test)
accuracyScore = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1Score = f1_score(y_test, y_pred)
print("Logistic Regression Accuracy Score: ", accuracyScore)
print("Logistic Regression Precison Score: ", precision)
print("Logistic Regression Recall Score: ", recall)
print("Logistic Regression F1 Score: ", f1Score)

print('\n')

lin_svc_model = LinearSVC()
lin_svc_model.fit(X_train, y_train)
y_pred = lin_svc_model.predict(X_test)
accuracyScore = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1Score = f1_score(y_test, y_pred)
print("Linear SVC Accuracy Score: ", accuracyScore)
print("Linear SVC Precison Score: ", precision)
print("Linear SVC Recall Score: ", recall)
print("Linear SVC F1 Score: ", f1Score)
# Out:
# Logistic Regression Accuracy Score:  0.7472527472527473
# Logistic Regression Precison Score:  0.7547169811320755
# Logistic Regression Recall Score:  0.8
# Logistic Regression F1 Score:  0.7766990291262136
#
#
# Linear SVC Accuracy Score:  0.7582417582417582
# Linear SVC Precison Score:  0.7592592592592593
# Linear SVC Recall Score:  0.82
# Linear SVC F1 Score:  0.7884615384615384

# %%
feat1 = 'age'
feat2 = 'thalach'
target = 'target'

plt.scatter(df[feat1], df[feat2], c=df[target])
plt.xlabel(feat1)
plt.ylabel(feat2)
plt.title("Age vs Maximum Heart Rate")
plt.show()

X = df[[feat1, feat2]]
y = df[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
log_reg_model = LogisticRegression()
log_reg_model.fit(X_train, y_train)
y_pred = log_reg_model.predict(X_test)
accuracyScore = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1Score = f1_score(y_test, y_pred)
print("Logistic Regression Accuracy Score: ", accuracyScore)
print("Logistic Regression Precison Score: ", precision)
print("Logistic Regression Recall Score: ", recall)
print("Logistic Regression F1 Score: ", f1Score)

print('\n')

lin_svc_model = LinearSVC()
lin_svc_model.fit(X_train, y_train)
y_pred = lin_svc_model.predict(X_test)
accuracyScore = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1Score = f1_score(y_test, y_pred)
print("Linear SVC Accuracy Score: ", accuracyScore)
print("Linear SVC Precison Score: ", precision)
print("Linear SVC Recall Score: ", recall)
print("Linear SVC F1 Score: ", f1Score)
# Out:
# Logistic Regression Accuracy Score:  0.7032967032967034
# Logistic Regression Precison Score:  0.7169811320754716
# Logistic Regression Recall Score:  0.76
# Logistic Regression F1 Score:  0.7378640776699029
#
#
# Linear SVC Accuracy Score:  0.7032967032967034
# Linear SVC Precison Score:  0.7090909090909091
# Linear SVC Recall Score:  0.78
# Linear SVC F1 Score:  0.7428571428571429

# %% [markdown]
# Problem 3 & 4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.svm import LinearSVC, SVC

df = pd.read_csv('heart.csv')
df.head(303)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
numeric_features = ['age', 'cp', 'trestbps', 'chol', 'thalach', 'oldpeak', 'slope', 'ca', 'thal']

X = df[numeric_features]
y = df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
log_reg_model = LogisticRegression()
log_reg_model.fit(X_train, y_train)
y_pred = log_reg_model.predict(X_test)
accuracyScore = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1Score = f1_score(y_test, y_pred)
print(f"Logistic Regression Accuracy Score: ", accuracyScore)
print(f"Logistic Regression Precison Score: ", precision)
print(f"Logistic Regression Recall Score: ", recall)
print(f"Logistic Regression F1 Score: ", f1Score)

print('\n')

lin_svc_model = LinearSVC()
lin_svc_model.fit(X_train, y_train)
y_pred = lin_svc_model.predict(X_test)
accuracyScore = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1Score = f1_score(y_test, y_pred)
print(f"Linear SVC Accuracy Score: ", accuracyScore)
print(f"Linear SVC Precison Score: ", precision)
print(f"Linear SVC Recall Score: ", recall)
print(f"Linear SVC F1 Score: ", f1Score)

print('\n')

kernel_svm_model = SVC()
kernel_svm_model.fit(X_train, y_train)
y_pred = kernel_svm_model.predict(X_test)
accuracyScore = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1Score = f1_score(y_test, y_pred)
print(f"Kernel SVM Accuracy Score: ", accuracyScore)
print(f"Kernel SVM Precison Score: ", precision)
print(f"Kernel SVM Recall Score: ", recall)
print(f"Kernel SVM F1 Score: ", f1Score)
# Out:
# Logistic Regression Accuracy Score:  0.8241758241758241
# Logistic Regression Precison Score:  0.8541666666666666
# Logistic Regression Recall Score:  0.82
# Logistic Regression F1 Score:  0.8367346938775511
#
#
# Linear SVC Accuracy Score:  0.8241758241758241
# Linear SVC Precison Score:  0.84
# Linear SVC Recall Score:  0.84
# Linear SVC F1 Score:  0.84
#
#
# Kernel SVM Accuracy Score:  0.6923076923076923
# Kernel SVM Precison Score:  0.6666666666666666
# Kernel SVM Recall Score:  0.88
# Kernel SVM F1 Score:  0.7586206896551724
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# QUESTION RESPONSES

# %% [markdown]
# 1. The features that we have chosen were “Age vs. Chol,” “Thalach vs. Oldpeak,” “Trestbps vs. Thalach,” and “Age vs. Thalach.” The reason for this is that when these features were plotted together in scatter plots, these were the combinations that seemed to have data that was most easily and noticeably separable.
#
# 2. There was barely any difference in the performance between the LinearSVC and logistic regression models. The reason for this could be that both of these models were able to select the ideal separation boundary, especially due to the fact that we have chosen four pairs of features that are almost linearly separable.
#
# 3. Based on the table 2 data, we observed that the performance of logistic regression and linear svc is almost the same as they seem to be choosing boundaries of linear separability that are similar as mentioned in number 2. Kernel SVM has much lower performance values (besides the recall). The recall may be something that is more specific to this dataset as recall focuses more on false negatives. Overall though, we believe that kernel svm values are lower because it may be overfitting on the training data due to its more complex, flexible nature putting data into a higher dimensional space. The decision boundaries may not generalize well in this scenario.
